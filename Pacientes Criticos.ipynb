# %% [markdown]
# ### Cargamos las librerias necesarias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Cargamos los datos

# %%
url  = "https://raw.githubusercontent.com/MinCiencia/Datos-COVID19/master/output/producto23/PacientesCriticos.csv"
data = pd.read_csv(url)
data
# Out:
#                 Casos  2020-03-27  2020-03-28  2020-03-29  2020-03-30  \
# 0  Pacientes criticos          10          11          14          13
#
#    2020-03-31  2020-04-02  2020-04-03  2020-04-04  2020-04-05  ...  \
# 0          20          31          29          38          36  ...
#
#    2020-06-02  2020-06-03  2020-06-04  2020-06-05  2020-06-06  2020-06-07  \
# 0         326         339         354         337         353         372
#
#    2020-06-08  2020-06-09  2020-06-10  2020-06-11
# 0         380         364         365         386
#
# [1 rows x 77 columns]

# %% [markdown]
# ## Pacientes criticos por fecha

# %%
fecha = data.columns[1:].tolist()
p_criticos = data[fecha].values.tolist()[0]

# %%
def labelonpoints(X, Y):
    n = len(X)
    for i in range (n):
        number = '{:,}'.format(int(Y[i])).replace(',', '.')
        plt.annotate(
            number, xy=(X[i], Y[i]),
            xytext =(0, 10),
            textcoords="offset points",
            ha ='center', va='bottom')

plt.figure(figsize=(20, 10), dpi=80)
plt.plot(fecha, p_criticos, 'o-')
plt.xticks(fecha, rotation='vertical')
labelonpoints(fecha, p_criticos)
plt.grid()
plt.show()
